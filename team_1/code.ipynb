# %% [markdown]
# # Code for AMC Research Sprint

# %% [markdown]
# Requirements:

# %%
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# Import data:

# %%
data_dir = Path("../data")

info = pd.read_csv(data_dir / "amcdata_agreement_info_V2.csv", encoding='latin-1')
vercom = pd.read_csv(data_dir / "amcdata_vercom_V2.csv", encoding='latin-1')
demcom = pd.read_csv(data_dir / "amcdata_demcom_V2.csv", encoding='latin-1')
consultation = pd.read_csv(data_dir / "amcdata_consultation_V2.csv", encoding='latin-1')
weapons = pd.read_csv(data_dir / "amcdata_weapons_facilities_V2.csv", encoding='latin-1')

# %% [markdown]
# And display head:

# %%
info.head()
# Out:
#    agreement_id  year                                             c_year  \
# 0             3  1817  Exchange of Notes Between the United Kingdom a...
# 1             6  1868  Declaration Renouncing the Use, in Time of War...
# 2             7  1906  General Act of the International Conference of...
# 3             8  1919  The Treaty of Peace between the Allied and Ass...
# 4            10  1921  Treaty between The United States of America,Th...
#
#                                           title_full  \
# 0  Exchange of Notes Between the United Kingdom a...
# 1  Declaration Renouncing the Use, in Time of War...
# 2  General Act of the International Conference of...
# 3  The Treaty of Peace between the Allied and Ass...
# 4  Four Power Treaty concerning insular possessio...
#
#                                         c_title_full  \
# 0  Exchange of Notes Between the United Kingdom a...
# 1  Declaration Renouncing the Use, in Time of War...
# 2  General Act of the International Conference of...
# 3  The Treaty of Peace between the Allied and Ass...
# 4                              Ibid. Document info.
#
#                     title_short  \
# 0          Rush-Bagot Agreement
# 1  Saint Petersburg Declaration
# 2           Algeciras Agreement
# 3          Treaty of Versailles
# 4             Four Power Treaty
#
#                                        c_title_short  \
# 0  Exchange of Notes Between the United Kingdom a...
# 1  Declaration Renouncing the Use, in Time of War...
# 2  General Act of the International Conference of...
# 3  The Treaty of Peace between the Allied and Ass...
# 4                                        Abbrivation
#
#         agreement_profile_title                         description  \
# 0          Rush-Bagot Agreement      Bilteral, Conventional Weapons
# 1  Saint Petersburg Declaration  Multilateral, Conventional Weapons
# 2           Algeciras Agreement  Multilateral, Conventional Weapons
# 3          Treaty of Versailles  Multilateral, Conventional Weapons
# 4             Four Power Treaty  Multilateral, Conventional Weapons
#
#    c_description  ...  agreement_association_established_nr  \
# 0            NaN  ...                                   0.0
# 1            NaN  ...                                   0.0
# 2            NaN  ...                                   0.0
# 3            NaN  ...                                   4.0
# 4            NaN  ...                                   NaN
#
#   c_agreement_association_established_nr  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#              agreement_association_established_title  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The Inter-Allied Commissions of Control and it...
# 4                                                NaN
#
#   c_agreement_association_established_title agreement_association_utlilized  \
# 0                                       NaN                             0.0
# 1                                       NaN                             0.0
# 2                                       NaN                             0.0
# 3                                       NaN                             0.0
# 4                                       NaN                             0.0
#
#    c_agreement_association_utlilized agreement_association_utilized_nr  \
# 0                                NaN                               0.0
# 1                                NaN                               0.0
# 2                                NaN                               0.0
# 3                                NaN                               0.0
# 4                                NaN                               NaN
#
#   c_agreement_association_utilized_nr  agreement_association_utilized_title  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#   c_agreement_association_utilized_title
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 271 columns]
